# %%
import pandas as pd
import numpy as np

# %%
agg17 = pd.read_csv('../data/2017/17_agg_data.csv')
agg18 = pd.read_csv('../data/2018/18_agg_data.csv')
agg19 = pd.read_csv('../data/2019/19_agg_data.csv')
agg20 = pd.read_csv('../data/2020/20_agg_data.csv')
pass

# %%
SIZE_17 = 4327
MEAN_TRACK = 61.055717
STD_TRACK = 9.868665
MEAN_WIND = 2.518879
STD_WIND = 5.040187

agg17['Track Temp'] = [MEAN_TRACK] * SIZE_17 #np.random.normal(MEAN_TRACK, STD_TRACK, SIZE_17)
agg17['Wind Speed'] = [MEAN_WIND] * SIZE_17 #np.random.normal(MEAN_WIND, STD_WIND, SIZE_17)
agg17 = agg17[['Time', 'Max Concentration', 'Last Pit', 'Track Temp', 'Wind Speed', 'Yellow']]

# %%
agg = pd.concat([agg18, agg19, agg20])
agg
# Out:
#          Time  Max Concentration   Last Pit  Air Temp  Track Temp  Humidity  \
# 0        20.0          27.407742   0.333333  71.90006    78.00008        62
# 1        40.0          22.615864   0.666667  71.90006    78.00008        62
# 2        60.0          12.329932   1.000000  71.99996    78.00008        62
# 3        80.0          20.322355   1.333333  71.99996    78.00008        62
# 4       100.0          11.667811   1.666667  71.99996    78.00008        62
# ...       ...                ...        ...       ...         ...       ...
# 4308  86300.0           2.976190  50.117750  64.00004    68.00000        43
# 4309  86320.0           2.826983  50.451083  64.00004    68.00000        43
# 4310  86340.0           3.826531  50.784417  64.00004    68.00000        43
# 4311  86360.0           2.803083  51.117750  64.00004    68.00000        43
# 4312  86380.0           4.118051  51.451083  64.00004    68.00000        43
#
#        Pressure  Wind Speed       Speed  Yellow
# ...

# %%
agg.to_csv('../data/agg_all.csv', index=False)
